# %%
from sklearn.datasets import fetch_openml
X_mnist , y_mnist = fetch_openml('mnist_784',version=1,return_X_y=True)
X_tsne , y_tsne = X_mnist[:5000], y_mnist[:5000]
# Out:
# c:\Users\MCS\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\datasets\_openml.py:74: RuntimeWarning: Invalid cache, redownloading file
#   warn("Invalid cache, redownloading file", RuntimeWarning)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from sklearn.manifold import TSNE

X_embedded = TSNE(n_components=2, learning_rate='auto',
                  init='random').fit_transform(X_tsne)

# %%
import matplotlib.pyplot as plt
y_tsne = y_tsne.astype(int)
scatter = plt.scatter(
    X_embedded[:, 0],   # X coordinate (1st dimension from t-SNE)
    X_embedded[:, 1],   # Y coordinate (2nd dimension from t-SNE)
    c=y_tsne,            # color each point according to its digit label
    cmap="tab10",   # a 10-color palette for digits 0–9
    s=10            # size of the points
)

# %%
import matplotlib.pyplot as plt

# Convert y to numpy if needed
y_np = y_tsne.to_numpy()

# X_embedded is already a NumPy array from TSNE
X_np = X_embedded

plt.figure(figsize=(10, 8))

for i in range(len(X_np)):
    plt.text(
        X_np[i, 0],
        X_np[i, 1],
        str(y_np[i]),
        color=plt.cm.tab10(y_np[i] / 9),   # normalize label 0–9 → 0–1
        fontdict={'size': 8}
    )

plt.title("t-SNE Visualization of Digits (Labels instead of Points)")
plt.show()
